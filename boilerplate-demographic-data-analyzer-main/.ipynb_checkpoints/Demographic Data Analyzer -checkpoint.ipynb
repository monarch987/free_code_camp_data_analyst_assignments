# %%
import numpy as np
import pandas as pd

# %%
## Read the csv data

# %%
data = pd.read_csv('adult_data.csv')

data.head(5)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
#How many people of each race are represented in this dataset? 

race = data.groupby('race').size()
# race
# print(type(race))

# race = data['race'].reset_index(label='race')
race
# Out:
# race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# dtype: int64

# %%
#What is the average age of men?
avg_age = data.groupby('sex')['age'].mean()
avg_age.loc['Male']
# Out:
# 39.43354749885268

# %%
#What is the percentage of people who have a Bachelor's degree?

#pandas-series
ed = data.groupby('education').size()

#summation of column education
total_populus = ed.sum()

percent_bachelor = (ed['Bachelors']/total_populus)*100

# print(type(ed))
# print(ed.loc['Bachelors'])
# print(ed.sum())
print(f"percent_bachelor::{percent_bachelor}")
# Out:
# percent_bachelor::16.44605509658794

# %%
#What percentage of people with advanced education (Bachelors, Masters, or Doctorate) make more than 50K?

#data-frame
# greater_than_50k = data[data['salary']=='>50K']

#series
# seria_a = greater_than_50k.groupby('education').size()

# total_educated_populus = data.groupby('education').size().sum()


# percent_adv_bachelor = (seria_a['Bachelors']/total_educated_populus)*100

# percent_adv_master = (seria_a['Masters']/total_educated_populus)*100

# percent_adv_Doctorate = (seria_a['Doctorate']/total_educated_populus)*100


#********************************************************************************************************#

#produce data frame with column called as count
advanced_ed = data.groupby(['education','salary']).size().reset_index(name='count')

#we further restrict df to only records > 50k , then we drop salary axis to spot count easily by making education as index label 
advanced_ed = ((advanced_ed[advanced_ed['salary'] == '>50K']).drop('salary',axis=1)).set_index('education') 

total_bachelors  = advanced_ed.loc['Bachelors','count']
 
total_masters  = advanced_ed.loc['Masters','count']

total_doctorates  = advanced_ed.loc['Doctorate','count']

total = advanced_ed['count'].sum()

portion_of_highly_educated = ((total_bachelors+total_masters+total_doctorates)/total)*100


print(portion_of_highly_educated)
# print(percent_adv_bachelor+percent_adv_master+percent_adv_Doctorate)
print(100-portion_of_highly_educated)

print(f"highly educated {total_bachelors+total_masters+total_doctorates}")

print(f"non highly educated {total -(total_bachelors+total_masters+total_doctorates)}")
# Out:
# 44.45861497258003
# 55.54138502741997
# highly educated 3486
# non highly educated 4355

# %%
#What percentage of people without advanced education make more than 50K?

# non_advanced_greater_than_50k = data[data['salary']=='>50K']
# non_adv_occupation  = non_advanced_greater_than_50k[~non_advanced_greater_than_50k['education'].isin(['Bachelors','Masters','Doctorate'])]
# non_adv_occupation.groupby('education').size()
#******************************************************

portion_of_non_highly_educated = (1 - ((total_bachelors+total_masters+total_doctorates)/total))*100
print(portion_of_non_highly_educated )
# Out:
# 55.54138502741996

# %%
#What percentage of people without advanced education make more than 50K?

total_adv_edu_percent_greater_than_50k = percent_adv_bachelor+percent_adv_master+percent_adv_Doctorate

non_adv_percent_greater_than_50k = 100 - total_adv_edu_percent_greater_than_50k

non_adv_percent_greater_than_50k
# Out:
# 51.65636921095242

# %%
#What is the minimum number of hours a person works per week?

minimum_no_hrs = data['hours-per-week'].min()

minimum_no_hrs
# Out:
# 1

# %%
#What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

no_of_people_slaried_greater_than_50k = data[data['salary']=='>50K']

working_min_hrs = (no_of_people_slaried_greater_than_50k[no_of_people_slaried_greater_than_50k['hours-per-week']==1])
len(working_min_hrs)
print(working_min_hrs['hours-per-week'].count())
# Out:
# 2

# %%
#What country has the highest percentage of people that earn >50K and what is that percentage?

#pandas-series
country_tops = no_of_people_slaried_greater_than_50k.groupby('native-country').size()

# print(country_tops)
summation_of_all_country = country_tops.sum()

# print(summation_country_tops)

max_people = country_tops.max()

#whats the percent shar
percent = (max_people/summation_of_all_country)*100


#which country tops the list
country = country_tops[country_tops == max_people].idxmax()
# country
print(percent,country)
# Out:
# 91.45517153424308 United-States

# %%
#What country has the highest percentage of people that earn >50K and what is that percentage?

populus_with_max_earning =  (data[data['salary']=='>50K']).groupby('native-country').size()

#we get max count then reset the count column as index  & then using max count we located the country
# max_count = country_with_max_earning['count'].max()
# total_count = country_with_max_earning['count'].sum()

populus_with_total_earning = (data.groupby('native-country')).size()

# ag = pd.concat([populus_with_total_earning,populus_with_max_earning],axis=1)


# richest_country= (country_with_max_earning.set_index('count')).loc[max_count,'native-country']
# richest_country
# print(populus_with_max_earning)
# print(ag)
print(populus_with_total_earning)
# Out:
#   File "/tmp/ipykernel_12712/3901613007.py", line 18
#     print(populus_with_total_earning)
#     ^
# SyntaxError: invalid syntax

# %%
#Identify the most popular occupation for those who earn >50K in India.

#dataframe
indian_populus = no_of_people_slaried_greater_than_50k[no_of_people_slaried_greater_than_50k['native-country']=='India']

#series
occupation_wise = indian_populus.groupby('occupation').size()
# print(occupation_wise)

most_prefered_occupation_count = occupation_wise.max()

most_prefered_occupation = occupation_wise[occupation_wise==most_prefered_occupation_count].idxmax()
most_prefered_occupation
# Out:
# 'Prof-specialty'
